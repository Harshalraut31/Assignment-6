# %%
#Assigment
#Referral ID:DIRSS3146
#Name: Harshal M. Raut

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student_marks_1.csv")

# %%
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of      number_courses  time_study   Marks
# 0                 3       4.508  19.202
# 1                 4       0.096   7.734
# 2                 4       3.133  13.811
# 3                 6       7.909  53.018
# 4                 8       7.811  55.299
# ..              ...         ...     ...
# 126               3       6.335  32.357
# 127               3       0.301   5.609
# 128               4       7.163  41.444
# 129               7       0.309  12.027
# 130               3       6.335  32.357
#
# [131 rows x 3 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      number_courses  time_study   Marks
# 0                 3       4.508  19.202
# 1                 4       0.096   7.734
# 2                 4       3.133  13.811
# 3                 6       7.909  53.018
# 4                 8       7.811  55.299
# ..              ...         ...     ...
# 126               3       6.335  32.357
# 127               3       0.301   5.609
# 128               4       7.163  41.444
# 129               7       0.309  12.027
# 130               3       6.335  32.357
#
# [131 rows x 3 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  131 non-null    int64
#  1   time_study      127 non-null    float64
#  2   Marks           122 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 3.2 KB

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        4
# Marks             9
# dtype: int64

# %%
df_mean=df['time_study'].replace(np.nan,df['time_study'].mean(),inplace=True)

# %%
df.head(30)
# Out:
#     number_courses  time_study   Marks
# 0                3     4.50800  19.202
# 1                4     0.09600   7.734
# 2                4     3.13300  13.811
# 3                6     7.90900  53.018
# 4                8     7.81100  55.299
# 5                6     3.21100  17.822
# 6                3     6.06300  29.889
# 7                5     3.41300  17.264
# 8                4     4.41000  20.348
# 9                3     6.17300  30.862
# 10               4     3.98489  11.397
# 11               2     3.98489  24.318
# 12               5     3.98489  24.318
# 13               3     3.98489  11.397
# 14               3     7.35300  42.036
# 15               7     0.42300  12.132
# 16               7     4.21800  24.318
# 17               3     4.27400  17.672
# 18               3     2.90800  11.397
# 19               4     4.26000  19.466
# 20               5     5.71900  30.548
# 21               8     6.08000  38.490
# 22               6     7.71100  50.986
# ...

# %%
df_tr2=df['time_study'].mean()
df['time_study'].replace(np.nan,df_tr2,inplace=True)

# %%
df_tr2
# Out:
# 3.9848899082568825

# %%
df_t1=df['Marks'].mean()
df['Marks'].replace(np.nan,df_t1,inplace=True)

# %%
#EDA
sns.countplot(x='Marks',data=df)

# %%
plt.figure(dpi=100)
sns.lineplot(df['time_study'],df['Marks'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.lineplot(df['number_courses'],df['Marks'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(x='Marks',y='number_courses',data=df)

# %%
sns.lineplot(x='Marks',y='time_study',data=df)

# %%
sns.lineplot(x='time_study',y='Marks',data=df)

# %%
sns.barplot(x='number_courses',y='time_study',data=df)

# %%
sns.barplot(x='number_courses',y='Marks',data=df)

# %%
sns.barplot(x='number_courses',y='Marks',hue='time_study',data=df)

# %%
sns.heatmap(df.corr())

# %%
sns.boxplot(x='Marks',data=df)

# %%
sns.boxplot(x='number_courses',y='Marks',data=df)

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
Y
# Out:
# 0      19.202
# 1       7.734
# 2      13.811
# 3      53.018
# 4      55.299
#         ...
# 122    19.128
# 123     5.609
# 124    41.444
# 125    12.027
# 126    32.357
# Name: Marks, Length: 113, dtype: float64

# %%
sns.relplot(x="number_courses",y='Marks',data=df)

# %%
#Splitting
from sklearn.model_selection import train_test_split
##dependent and independant variable
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=5)

# %%
print("Train data shape:",X_train.shape)
print('Testing data shape:',X_test.shape)
# Out:
# Train data shape: (84, 2)
# Testing data shape: (29, 2)

# %%
print("Dependant variable training:",Y_train.shape)
print("dependent variable training:",Y_test.shape)
# Out:
# Dependant variable training: (84,)
# dependent variable training: (29,)

# %%
#Training 
from sklearn.linear_model import LinearRegression
regression =LinearRegression()
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
#Accuracy
regression.score(X_test,Y_test)
# Out:
# 0.8910765864067242

# %%
regression.predict(X_train)
# Out:
# array([23.89420862, 46.95192055, 32.57988066, 23.82144449, 16.88708211,
#        23.78092003,  5.20719576, 19.91880162, 19.87839663, 25.45869727,
#        29.04827515,  4.44323208, 11.97792844, 16.792429  , 44.49734371,
#         3.21594366, 14.39973154, 19.9589115 ,  8.22566478, 28.08175475,
#        21.27706548, 39.79796343, 36.11858338,  8.80056119,  7.37320127,
#         6.23926362, 36.21690457,  9.26625166, 47.37028446, 26.43610242,
#        13.19669784, 44.76781362, 44.11778734, 17.92713494, 39.28258067,
#         4.45293396, 31.27864524, 35.3946101 , 23.16420153, 20.35432303,
#         8.98359466, 17.69718949, 31.54165952, 40.38492745, 25.68184062,
#        14.82531213, 48.19494466, 22.41597354, 47.12773734, 21.97808639,
#         9.85191334, 23.67591621,  2.96487752, 28.08175475, 41.7311237 ,
#        30.49279258, 14.65446576, 39.3371239 , 23.54730651, 13.36399561,
#        12.00336602, 14.32578454, 16.66512163,  8.45011047,  3.17831899,
# ...

# %%
regression.predict(X_test)
# Out:
# array([38.38882441, 40.04417862, 20.62230773, 21.28085303, 29.59643163,
#        21.82965833, 38.44466998, 19.76120573, 37.69632252, 29.95918892,
#        22.48376726,  9.87628753, 29.31507698, 24.16716373, 20.91821522,
#        29.04839462, 19.91880162, 37.24648722, 32.19298814, 46.53107143,
#        27.88298559, 37.13858362, 41.69468189, 20.13236255, 28.63961312,
#        43.80732703, 38.91757713, 10.54571757, 24.17923135])

# %%
#Accuracy
regression.score(X_test,Y_test)
# Out:
# 0.8910765864067242

# %%
regression.score(X_train,Y_train)
# Out:
# 0.8697980122500455

# %%
plt.plot(X_test,Y_test,color='blue',label='data points')

# %%
plt.plot(X_train,Y_train,color='blue',label='data points');

# %%
# plt.scatter(X_train,Y_train,color='blue',label='data points')#;
#plt.plot(X_train,regression.predict(X_train),color='red',label='line')
